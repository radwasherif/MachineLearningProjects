# %% [markdown]
# # Task 1

# %%
# imports needed for task 1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn import metrics
from sklearn.cross_validation import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
# Out:
# /anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# **Reading the csv file:**

# %%
df = pd.read_csv('sp500_27270.csv')

# %% [markdown]
# **Finding the stocks with correlation >= 0.95 or <= -0.95:**

# %%
corr = df.corr()
x = dict(corr["SP500"])
inputs = [pair[0] for pair in x.items() if pair[1] >= 0.95 or pair[1] <= -0.95]

# %% [markdown]
# **Splitting the data into training and testing sets, then normalizing them:**

# %%
X = np.array(df[inputs])
y = np.array(df['SP500'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

mean_y_test = y_test.mean()
std_y_test = y_test.std()

y_train = (y_train - y_train.mean())/y_train.std()
y_test = (y_test - mean_y_test)/std_y_test
X_train = (X_train - X_train.mean())/X_train.std()
X_test = (X_test - X_test.mean())/X_test.std()

# %% [markdown]
# # Train the neural network with the sgd optimizers

# %% [markdown]
# **Try with learning rate: 0.001, which is the default learning rate:**

# %%
reg_sgd = MLPRegressor(hidden_layer_sizes = (36, 10), solver='sgd', alpha=0.001, learning_rate='constant', 
                       verbose=True, early_stopping=True)

# %%
reg_sgd.fit(X_train, y_train)
y1_predicted = reg_sgd.predict(X_test)
metrics.mean_squared_error(y_test, y1_predicted)
# Out:
# Iteration 1, loss = 1.07382822
# Validation score: -0.141527
# Iteration 2, loss = 0.50541001
# Validation score: 0.073690
# Iteration 3, loss = 0.43036334
# Validation score: 0.246894
# Iteration 4, loss = 0.33972177
# Validation score: 0.418142
# Iteration 5, loss = 0.27378605
# Validation score: 0.493115
# Iteration 6, loss = 0.24637278
# Validation score: 0.537723
# Iteration 7, loss = 0.22420309
# Validation score: 0.584682
# Iteration 8, loss = 0.19957041
# Validation score: 0.635792
# Iteration 9, loss = 0.17518101
# Validation score: 0.682843
# Iteration 10, loss = 0.15197185
# Validation score: 0.727293
# Iteration 11, loss = 0.13040536
# Validation score: 0.769175
# Iteration 12, loss = 0.11125634
# Validation score: 0.805371
# Iteration 13, loss = 0.09332244
# Validation score: 0.837084
# Iteration 14, loss = 0.07782966
# Validation score: 0.867348
# Iteration 15, loss = 0.06440091
# Validation score: 0.891937
# Iteration 16, loss = 0.05266110
# Validation score: 0.912209
# ...

# %% [markdown]
# **Try with learning rate: 0.1**

# %%
reg2_sgd = MLPRegressor(hidden_layer_sizes = (36, 10), solver='sgd', alpha=0.001, learning_rate='constant', 
                       learning_rate_init=0.1, verbose=True, early_stopping=True)

# %%
reg2_sgd.fit(X_train, y_train)
y2_predicted = reg2_sgd.predict(X_test)
metrics.mean_squared_error(y_test, y2_predicted)
# Out:
# Iteration 1, loss = 6.24184654
# Validation score: -0.170728
# Iteration 2, loss = 0.59824327
# Validation score: -0.075550
# Iteration 3, loss = 0.56962513
# Validation score: -0.168179
# Iteration 4, loss = 0.58245631
# Validation score: -0.039864
# Iteration 5, loss = 0.58053420
# Validation score: -0.025544
# Iteration 6, loss = 0.58781775
# Validation score: -0.031002
# Iteration 7, loss = 0.59165027
# Validation score: -0.039848
# Iteration 8, loss = 0.59408667
# Validation score: -0.042764
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# 1.0002421937500843

# %% [markdown]
# **Try with learning rate: 0.005**

# %%
reg_sgd3 = MLPRegressor(hidden_layer_sizes = (36, 10), solver='sgd', alpha=0.001, learning_rate='constant', 
                       learning_rate_init=0.005, verbose=True, early_stopping=True)

# %%
reg_sgd3.fit(X_train, y_train)
y3_predicted = reg_sgd3.predict(X_test)
metrics.mean_squared_error(y_test, y3_predicted)
# Out:
# Iteration 1, loss = 0.83543404
# Validation score: -0.128881
# Iteration 2, loss = 0.38516522
# Validation score: 0.449803
# Iteration 3, loss = 0.27412794
# Validation score: 0.606878
# Iteration 4, loss = 0.17958846
# Validation score: 0.762428
# Iteration 5, loss = 0.10731143
# Validation score: 0.883588
# Iteration 6, loss = 0.05083239
# Validation score: 0.962252
# Iteration 7, loss = 0.01893814
# Validation score: 0.984814
# Iteration 8, loss = 0.01102159
# Validation score: 0.979284
# Iteration 9, loss = 0.01204064
# Validation score: 0.975540
# Iteration 10, loss = 0.01218037
# Validation score: 0.978937
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# 0.023031210603803316

# %% [markdown]
# **Try with learning rate: 0.5**

# %%
reg4_sgd = MLPRegressor(hidden_layer_sizes = (36, 10), solver='sgd', alpha=0.001, learning_rate='constant', 
                       learning_rate_init=0.5, verbose=True, early_stopping=True)

# %%
reg4_sgd.fit(X_train, y_train)
y4_predicted = reg4_sgd.predict(X_test)
metrics.mean_squared_error(y_test, y4_predicted)
# Out:
# Iteration 1, loss = 11540602659042398356232693094547456.00000000
# Validation score: -1209372299336969556120829952.000000
# Iteration 2, loss = 272081474768562147455812498182111232.00000000
# Validation score: -5464474553141662056448.000000
# Iteration 3, loss = 674323653059248433680163869688856576.00000000
# Validation score: -393651143926886191595520.000000
# Iteration 4, loss = 1003442523998361631512361111419617280.00000000
# Validation score: -15062676521795568271360.000000
# Iteration 5, loss = 1229604225583877115129711644085583872.00000000
# Validation score: -147939712899091988480.000000
# Iteration 6, loss = 1374122444080612246301333401165103104.00000000
# Validation score: -7757691015486913.000000
# Iteration 7, loss = 1463160160307436807558511315581403136.00000000
# Validation score: -43016775065877672.000000
# Iteration 8, loss = 1516901609736353804795695881655418880.00000000
# Validation score: -1742663763249714.000000
# ...

# %% [markdown]
# **Try with learning rate: 0.0001**

# %%
reg5_sgd = MLPRegressor(hidden_layer_sizes = (36, 10), solver='sgd', alpha=0.001, learning_rate='constant', 
                       learning_rate_init=0.0001, verbose=True, early_stopping=True)

# %%
reg5_sgd.fit(X_train, y_train)
y5_predicted = reg5_sgd.predict(X_test)
metrics.mean_squared_error(y_test, y5_predicted)
# Out:
# Iteration 1, loss = 0.55404448
# Validation score: -0.109953
# Iteration 2, loss = 0.52796230
# Validation score: -0.024476
# Iteration 3, loss = 0.48849864
# Validation score: 0.061379
# Iteration 4, loss = 0.45759307
# Validation score: 0.112398
# Iteration 5, loss = 0.43738086
# Validation score: 0.154251
# Iteration 6, loss = 0.42033625
# Validation score: 0.193165
# Iteration 7, loss = 0.40322467
# Validation score: 0.218469
# Iteration 8, loss = 0.39409826
# Validation score: 0.231068
# Iteration 9, loss = 0.38937819
# Validation score: 0.242099
# Iteration 10, loss = 0.38487920
# Validation score: 0.251808
# Iteration 11, loss = 0.38047850
# Validation score: 0.260633
# Iteration 12, loss = 0.37635356
# Validation score: 0.269745
# Iteration 13, loss = 0.37213388
# Validation score: 0.278636
# Iteration 14, loss = 0.36794828
# Validation score: 0.287266
# Iteration 15, loss = 0.36381685
# Validation score: 0.295538
# Iteration 16, loss = 0.35970334
# ...

# %% [markdown]
# # Train the neural network with both the adam optimizers

# %% [markdown]
# **Train with learning rate = 0.001**

# %%
reg1_adam = MLPRegressor(hidden_layer_sizes = (36), solver='adam', alpha=0.001, learning_rate_init=0.001, 
                        verbose=True, early_stopping=True)

# %%
reg1_adam.fit(X_train, y_train)
y6_predicted = reg1_adam.predict(X_test)
metrics.mean_squared_error(y_test, y6_predicted)
# Out:
# Iteration 1, loss = 0.34956259
# Validation score: 0.470692
# Iteration 2, loss = 0.22743845
# Validation score: 0.673658
# Iteration 3, loss = 0.13629053
# Validation score: 0.822018
# Iteration 4, loss = 0.07217248
# Validation score: 0.916596
# Iteration 5, loss = 0.03297241
# Validation score: 0.967370
# Iteration 6, loss = 0.01354709
# Validation score: 0.984462
# Iteration 7, loss = 0.00938051
# Validation score: 0.981781
# Iteration 8, loss = 0.01130429
# Validation score: 0.977550
# Iteration 9, loss = 0.01238347
# Validation score: 0.979002
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# 0.020438914812628738

# %% [markdown]
# **Try with learning rate = 0.1**

# %%
reg2_adam = MLPRegressor(hidden_layer_sizes = (36), solver='adam', alpha=0.001, learning_rate_init=0.1, 
                        verbose=True, early_stopping=True)

# %%
reg2_adam.fit(X_train, y_train)
y7_predicted = reg2_adam.predict(X_test)
metrics.mean_squared_error(y_test, y7_predicted)
# Out:
# Iteration 1, loss = 6.52544967
# Validation score: -0.261945
# Iteration 2, loss = 0.35514328
# Validation score: 0.621377
# Iteration 3, loss = 0.09598996
# Validation score: 0.819513
# Iteration 4, loss = 0.05412724
# Validation score: 0.864216
# Iteration 5, loss = 0.04124217
# Validation score: 0.904807
# Iteration 6, loss = 0.02455639
# Validation score: 0.934924
# Iteration 7, loss = 0.01897639
# Validation score: 0.951101
# Iteration 8, loss = 0.01601995
# Validation score: 0.964037
# Iteration 9, loss = 0.01440949
# Validation score: 0.964915
# Iteration 10, loss = 0.01347824
# Validation score: 0.966512
# Iteration 11, loss = 0.01275070
# Validation score: 0.968324
# Iteration 12, loss = 0.01246760
# Validation score: 0.968647
# Iteration 13, loss = 0.01224635
# Validation score: 0.970133
# Iteration 14, loss = 0.01160604
# Validation score: 0.969548
# Iteration 15, loss = 0.01137913
# Validation score: 0.970925
# Iteration 16, loss = 0.01110472
# Validation score: 0.972206
# ...

# %% [markdown]
# **Try with learning rate = 0.005**

# %%
reg3_adam = MLPRegressor(hidden_layer_sizes = (36), solver='adam', alpha=0.001, learning_rate_init=0.005, 
                        verbose=True, early_stopping=True)

# %%
reg3_adam.fit(X_train, y_train)
y8_predicted = reg3_adam.predict(X_test)
metrics.mean_squared_error(y_test, y8_predicted)
# Out:
# Iteration 1, loss = 0.34093099
# Validation score: 0.722157
# Iteration 2, loss = 0.06581694
# Validation score: 0.984347
# Iteration 3, loss = 0.02166305
# Validation score: 0.910853
# Iteration 4, loss = 0.04821322
# Validation score: 0.950388
# Iteration 5, loss = 0.01947078
# Validation score: 0.983617
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# 0.017963541338378526

# %% [markdown]
# **Try with learning rate = 0.5**

# %%
reg4_adam = MLPRegressor(hidden_layer_sizes = (36), solver='adam', alpha=0.001, learning_rate_init=0.5, 
                        verbose=True, early_stopping=True)

# %%
reg4_adam.fit(X_train, y_train)
y9_predicted = reg4_adam.predict(X_test)
metrics.mean_squared_error(y_test, y9_predicted)
# Out:
# Iteration 1, loss = 1568.06590148
# Validation score: -8.433851
# Iteration 2, loss = 12.99227514
# Validation score: -0.095151
# Iteration 3, loss = 0.79449664
# Validation score: -0.634390
# Iteration 4, loss = 0.99598601
# Validation score: -0.808058
# Iteration 5, loss = 1.07369126
# Validation score: -0.842468
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# 1.2029265502753839

# %% [markdown]
# **Try with learning rate = 0.0001**

# %%
reg5_adam = MLPRegressor(hidden_layer_sizes = (36), solver='adam', alpha=0.001, learning_rate_init=0.0001, 
                        verbose=True, early_stopping=True)

# %%
reg5_adam.fit(X_train, y_train)
y10_predicted = reg5_adam.predict(X_test)
metrics.mean_squared_error(y_test, y10_predicted)
# Out:
# Iteration 1, loss = 3.89150673
# Validation score: -7.593475
# Iteration 2, loss = 3.77413004
# Validation score: -7.342753
# Iteration 3, loss = 3.65868965
# Validation score: -7.096155
# Iteration 4, loss = 3.54817995
# Validation score: -6.852693
# Iteration 5, loss = 3.43856778
# Validation score: -6.614144
# Iteration 6, loss = 3.33014252
# Validation score: -6.380963
# Iteration 7, loss = 3.22631304
# Validation score: -6.151427
# Iteration 8, loss = 3.12400237
# Validation score: -5.926189
# Iteration 9, loss = 3.02391770
# Validation score: -5.705341
# Iteration 10, loss = 2.92647027
# Validation score: -5.489643
# Iteration 11, loss = 2.83023767
# Validation score: -5.280349
# Iteration 12, loss = 2.73714423
# Validation score: -5.076751
# Iteration 13, loss = 2.64576258
# Validation score: -4.878324
# Iteration 14, loss = 2.55799945
# Validation score: -4.684719
# Iteration 15, loss = 2.47297910
# Validation score: -4.496715
# Iteration 16, loss = 2.39006791
# ...

# %% [markdown]
# **Using the best performing neural network configuration, plot the predicted values for S&P versus the true values in the test set. Your plot should show 200 time points or more.**

# %% [markdown]
# **Denormalizing the data to reflect actual stock values.**

# %%
y_test = y_test*std_y_test + mean_y_test
y_predict = y8_predicted*std_y_test + mean_y_test

# %%
plt.plot(y_predict, label='predicted')
plt.plot(y_test, label='actual')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Task 2

# %% [markdown]
# **Finding feature with maximum correlation to SP500.**

# %%
df = pd.read_csv('sp500.csv')
corr = df.corr()
corr = dict(corr['SP500'])
del corr['SP500']
max_corr = [key for (key, val) in corr.items() if val == max(corr.values())][0]

# %% [markdown]
# **Function to prepare the dataset:**

# %%
def prepare_time_series(feature_name, df, time_samples=9, split_index=5):
    assert time_samples > split_index
    col = df[feature_name]
    df = pd.concat([col]*time_samples, axis=1)
    idx = ['T' + str(i) for i in range(time_samples)]
    df.columns = idx 
    for i in range(time_samples):
        df[idx[i]] = df[idx[i]].shift(-i)
    df = df.dropna()
    X = np.array(df[idx[:split_index]])
    y = np.array(df[idx[split_index:]])
    return X, y

# %% [markdown]
# **Normalize dataset and split into testing and training.**

# %%
X, y = prepare_time_series(max_corr, df)
scalerX = StandardScaler().fit(X)
scalerY = StandardScaler().fit(y)
X = scalerX.transform(X)
y = scalerY.transform(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# **Regression neural network, with 2 layers one with 5 nodes and another with 3.
# Adaptive solver, using an initial learning rate of 0.005 and early stopping to avoid over-fitting.**

# %%
reg = MLPRegressor(hidden_layer_sizes=(5, 3), solver='adam', learning_rate_init=0.005, early_stopping=True)
reg.fit(X_train, y_train)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=True, epsilon=1e-08,
#        hidden_layer_sizes=(5, 3), learning_rate='constant',
#        learning_rate_init=0.005, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_predict = reg.predict(X_test)
mse = metrics.mean_squared_error(y_predict, y_test)
print(mse)
# Out:
# 0.009281079773266823

# %% [markdown]
# **Denormalizing the data to reflect actual stock values.**

# %%
y_predict = scalerY.inverse_transform(y_predict)
y_test = scalerY.inverse_transform(y_test)

# %%
plt.plot(y_predict[50], label='predicted')
plt.plot(y_test[50], label='actual')
plt.xticks([0, 1, 2, 3, 4], ['Day 1', 'Day 2', 'Day 3', 'Day 4'])
plt.legend()
plt.show()

# %%
plt.plot(y_predict[150], label='predicted')
plt.plot(y_test[150], label='actual')
plt.xticks([0, 1, 2, 3], ['Day 1', 'Day 2', 'Day 3', 'Day 4'])
plt.legend()
plt.show()

# %%
plt.plot(y_predict[250], label='predicted')
plt.plot(y_test[250], label='actual')
plt.xticks([0, 1, 2, 3], ['Day 1', 'Day 2', 'Day 3', 'Day 4'])
plt.legend()
plt.show()

# %% [markdown]
# # Task 3

# %%
import numpy as np
import pandas as pd
import json as js
import seaborn as sns
from sklearn import metrics
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_json('reviews_Digital_Music_5.json', lines=True)
print(df.groupby(['overall']).size())

df1 = df[df['overall'] == 1].iloc[:2500]
df2 = df[df['overall'] == 2].iloc[:2500]
df3 = df[df['overall'] == 3].iloc[:2500]
df4 = df[df['overall'] == 4].iloc[:2500]
df5 = df[df['overall'] == 5].iloc[:2500]

df = df1.append(df2).append(df3).append(df4).append(df5)
df = df.sample(frac=1)
# Out:
# overall
# 1     2791
# 2     3010
# 3     6789
# 4    16536
# 5    35580
# dtype: int64

# %%
# Out:
#              asin   helpful  overall  \
# 7086   B00000252W    [1, 1]        4
# 51860  B000EGFV4K    [4, 4]        1
# 1567   B000000ORH    [4, 6]        5
# 6286   B000001Y61    [0, 1]        4
# 2155   B000000WZ4    [1, 1]        5
# 11163  B000002BSG    [0, 1]        4
# 5603   B000001FUB  [11, 12]        4
# 3639   B000001DUP    [2, 2]        4
# 55037  B000UMQDHC  [15, 22]        2
# 7667   B0000025CY    [1, 2]        3
# 9290   B0000026T4    [1, 1]        3
# 5255   B000001FC0  [17, 18]        4
# 10322  B0000029B3    [0, 0]        4
# 24053  B000005HN6    [2, 8]        3
# 20483  B000002ULS    [0, 1]        1
# 15476  B000002KKN    [1, 4]        2
# 16926  B000002LGQ   [4, 18]        2
# 44016  B0000CD5F1    [1, 1]        1
# 11875  B000002GJB    [1, 1]        3
# 20064  B000002R0R   [7, 10]        2
# 17529  B000002MFQ    [0, 2]        3
# 14656  B000002KBB    [2, 9]        3
# 742    B00000054H    [2, 2]        5
# 9499   B000002735    [0, 0]        4
# ...

# %%
X = np.array(df['reviewText'])
y = np.array(df['overall'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#You need to define X_train and X_test
tfidf_vectorizer = TfidfVectorizer(max_features=40000)
X_train = tfidf_vectorizer.fit_transform(X_train)
X_test = tfidf_vectorizer.transform(X_test)
# Out:
# ['Even a mixed-bag Streisand album is still eons better than most pop music and "ButterFly" is no exception. The song choice could be called \'eclectic\' at best and unfortunate at worst. There\'s certainly no quibbling about "Love in the Afternoon" or "Simple Man", which feature some of Barbra\'s loveliest singing. I\'ve always loved the sexy and playful "Guava Jelly", the gospel-tinged "Grandma\'s Hands" and "Crying Time" as well.  Okay, so David Bowie trounced her version of "Life on Mars"; I don\'t think it\'s all that bad, just a little melodramatic.  "I Won\'t Last A Day Without You" was a Carpenters hit and should have stayed just that--it\'s not that profound a love song and even Barbra can\'t alter those insipid lyrics. That leaves "Jubilation" (I like it); "Since I Don\'t Have You" (over-produced) and the innocuous "Let the Good Times Roll".  So, it\'s definitely worth buying but there\'s a reason why Jon Peters never solo-produced another Streisand album--he simply didn\'t
# ...

# %%
mlp = MLPClassifier(hidden_layer_sizes=(1000, 512), solver='adam', learning_rate_init=0.001, early_stopping=True, verbose=True, max_iter=1000)

# %%
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 1.19693579
# Validation score: 0.607000
# Iteration 2, loss = 0.39292439
# Validation score: 0.572000
# Iteration 3, loss = 0.07985986
# Validation score: 0.568000
# Iteration 4, loss = 0.01566309
# Validation score: 0.570000
# Iteration 5, loss = 0.00574878
# Validation score: 0.575000
# Iteration 6, loss = 0.00390836
# Validation score: 0.578000
# Iteration 7, loss = 0.00314662
# Validation score: 0.578000
# Iteration 8, loss = 0.00270780
# Validation score: 0.580000
# Iteration 9, loss = 0.00243410
# Validation score: 0.584000
# Iteration 10, loss = 0.00225358
# Validation score: 0.577000
# Iteration 11, loss = 0.00212793
# Validation score: 0.578000
# Iteration 12, loss = 0.00203924
# Validation score: 0.576000
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=True, epsilon=1e-08,
# ...

# %%
y_predict = mlp.predict(X_test)

# %%
metrics.accuracy_score(y_test, y_predict)
# Out:
# 0.6128

# %%
cm = metrics.confusion_matrix(y_test, y_predict)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cm
# Out:
# array([[0.80638723, 0.11377246, 0.0499002 , 0.01796407, 0.01197605],
#        [0.31325301, 0.40763052, 0.24899598, 0.02208835, 0.00803213],
#        [0.04752852, 0.14828897, 0.5608365 , 0.20152091, 0.0418251 ],
#        [0.0422833 , 0.02325581, 0.24312896, 0.52642706, 0.16490486],
#        [0.03784861, 0.00199203, 0.03784861, 0.16334661, 0.75896414]])

# %%
sns.heatmap(cm, annot=True, xticklabels=[1, 2, 3, 4, 5], yticklabels=[1, 2, 3, 4, 5])

# %%
df = pd.read_json('reviews_Digital_Music_5.json', lines=True)
df.groupby(['overall']).size()

df1 = df[df['overall'] == 1].iloc[:2791]
df2 = df[df['overall'] == 2].iloc[:2791]
df3 = df[df['overall'] == 3].iloc[:2791]
df4 = df[df['overall'] == 4].iloc[:2791]
df5 = df[df['overall'] == 5].iloc[:2791]

df = df1.append(df2).append(df3).append(df4).append(df5)
print(df)
df = df.sample(frac=1)
X = np.array(df['reviewText'])
y = np.array(df['overall'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#You need to define X_train and X_test
tfidf_vectorizer = TfidfVectorizer(max_features=50000)
X_train = tfidf_vectorizer.fit_transform(X_train)
X_test = tfidf_vectorizer.transform(X_test)
# Out:
#             asin   helpful  overall  \
# 30    B0000000ZW    [2, 9]        1
# 86    B00000016W   [4, 29]        1
# 94    B00000016W  [19, 24]        1
# 95    B00000016W  [18, 73]        1
# 167   B00000016W  [13, 65]        1
# 382   B0000004VW   [3, 17]        1
# 427   B0000004YH   [2, 17]        1
# 690   B00000053X    [2, 8]        1
# 695   B00000053X   [5, 17]        1
# 696   B00000053X    [0, 1]        1
# 700   B00000053X    [2, 7]        1
# 807   B0000005XM   [5, 18]        1
# 808   B0000005XM  [26, 66]        1
# 938   B00000064G   [7, 58]        1
# 1063  B0000009UW   [2, 19]        1
# 1137  B000000EDW    [1, 4]        1
# 1166  B000000HJO    [0, 4]        1
# 1174  B000000HKV   [3, 24]        1
# 1179  B000000HKV    [5, 6]        1
# 1188  B000000HLL   [2, 12]        1
# 1190  B000000HLL    [0, 5]        1
# 1193  B000000HQ1   [5, 30]        1
# 1335  B000000ISE    [7, 8]        1
# 1348  B000000OB7   [1, 18]        1
# 1453  B000000OPZ   [3, 30]        1
# ...

# %%
mlp = MLPClassifier(hidden_layer_sizes=(1000, 512), solver='adam', learning_rate_init=0.005, early_stopping=True, verbose=True, max_iter=1000)

# %%
mlp.fit(X_train, y_train)
y_predict = mlp.predict(X_test)
metrics.accuracy_score(y_test, y_predict)
# Out:
# Iteration 1, loss = 1.08527602
# Validation score: 0.612355
# Iteration 2, loss = 0.25934840
# Validation score: 0.581916
# Iteration 3, loss = 0.04091511
# Validation score: 0.585497
# Iteration 4, loss = 0.01614338
# Validation score: 0.601611
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# 0.5969186671443927

# %%
cm = metrics.confusion_matrix(y_test, y_predict)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(cm, annot=True, xticklabels=[1, 2, 3, 4, 5], yticklabels=[1, 2, 3, 4, 5])
